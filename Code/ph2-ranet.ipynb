# %% [markdown]
# ## Import libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import cv2
from glob import glob
import tensorflow as tf
import tensorflow.keras as keras
import keras.backend as K
import tensorflow.keras.layers as L
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, MaxPool2D, Add, Dropout, Concatenate, Conv2DTranspose, Dense, Reshape, Flatten, Softmax, Lambda, UpSampling2D, AveragePooling2D, Activation, BatchNormalization, GlobalAveragePooling2D, GlobalMaxPooling2D, SeparableConv2D,Multiply
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanIoU
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import BinaryAccuracy, Precision, Recall
from tensorflow.keras.applications import ResNet50
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from sklearn.model_selection import train_test_split
import pandas as pd
# Out:
# 2024-06-12 07:54:28.668880: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-12 07:54:28.668929: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-12 07:54:28.670644: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from sklearn.datasets import make_blobs
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import Callback
from keras.optimizers import SGD
from keras import backend
from math import pi
from math import cos
from math import floor

# %% [markdown]
# ## Dataloader

# %%
class ISICDataLoader:
    def __init__(self, data_dir, image_size=(256, 256), batch_size=8, mode='train'):
        self.data_dir = data_dir
        self.image_size = image_size
        self.batch_size = batch_size
        self.mode = mode

        # Load CSV files based on the mode
        if self.mode == 'train':
            csv_filename = "/kaggle/input/isic-2017-segmentation/train_ph2.csv"
        elif self.mode == 'val':
            csv_filename = "/kaggle/input/isic-2017-segmentation/val_ph2.csv"
        else:
            csv_filename = "/kaggle/input/isic-2017-segmentation/test_ph2.csv"

        self.csv_path = os.path.join(self.data_dir, csv_filename)
        self.df = pd.read_csv(self.csv_path)

        # Define image and mask paths
        self.image_path = os.path.join(self.data_dir, "Images")
        self.mask_path = os.path.join(self.data_dir, "Masks")

        # Initialize the current batch index to 0
        self.current_batch_index = 0

    def __len__(self):
        return int(np.ceil(len(self.df) / float(self.batch_size)))

    def __iter__(self):
        while self.current_batch_index < len(self.df):
            batch_images = []
            batch_masks = []
            for i in range(self.current_batch_index, min(self.current_batch_index + self.batch_size, len(self.df))):
                image_name = self.df.iloc[i]['Image_Name']
                mask_name = image_name[:-4]+'_lesion'+'.bmp'

                image = load_img(os.path.join(self.image_path, image_name), target_size=self.image_size)
                mask = load_img(os.path.join(self.mask_path, mask_name), target_size=self.image_size, color_mode='grayscale')

                image_arr = img_to_array(image) / 255.0
                mask_arr = img_to_array(mask) / 255.0

                batch_images.append(image_arr)
                batch_masks.append(mask_arr)

            batch_images = np.array(batch_images)
            batch_masks = np.array(batch_masks)

            # Update the current batch index for the next iteration
            self.current_batch_index += self.batch_size

            yield batch_images, batch_masks
            
        # Reset the current batch index at the end of one epoch
        self.current_batch_index = 0

# %%
train_data_loader = ISICDataLoader(data_dir='/kaggle/input/isic-2017-segmentation/Arranged_PH2_dataset/Arranged_PH2_dataset', image_size=(512, 512), batch_size=4, mode='train')
val_data_loader = ISICDataLoader(data_dir='/kaggle/input/isic-2017-segmentation/Arranged_PH2_dataset/Arranged_PH2_dataset', image_size=(512, 512), batch_size=4, mode='val')
test_data_loader = ISICDataLoader(data_dir='/kaggle/input/isic-2017-segmentation/Arranged_PH2_dataset/Arranged_PH2_dataset', image_size=(512, 512), batch_size=4, mode='test')

train_dataset = tf.data.Dataset.from_generator(lambda: train_data_loader, output_signature=(tf.TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32), tf.TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32)))
val_dataset = tf.data.Dataset.from_generator(lambda: val_data_loader, output_signature=(tf.TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32), tf.TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32)))
test_dataset = tf.data.Dataset.from_generator(lambda: test_data_loader, output_signature=(tf.TensorSpec(shape=(None, 512, 512, 3), dtype=tf.float32), tf.TensorSpec(shape=(None, 512, 512, 1), dtype=tf.float32)))

# %% [markdown]
# ## Metrics and Losses

# %% [markdown]
# #### Metrics

# %%
def dice_score(y_true, y_pred):
    smooth = K.epsilon()
    y_true_flat = K.flatten(K.cast(y_true, 'float32'))
    y_pred_flat = K.flatten(y_pred)
    intersection = K.sum(y_true_flat * y_pred_flat)
    score = (2. * intersection + smooth) / (K.sum(y_true_flat) + K.sum(y_pred_flat) + smooth)
    return score

def iou(y_true, y_pred):
    smooth = K.epsilon()
    y_true_flat = K.flatten(K.cast(y_true, 'float32'))
    y_pred_flat = K.flatten(y_pred)
    intersection = K.sum(y_true_flat * y_pred_flat)
    union = K.sum(y_true_flat) + K.sum(y_pred_flat) - intersection + smooth
    iou = (intersection + smooth) / union
    return iou

def recall(y_true, y_pred):
    smooth = K.epsilon()
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_true_flat = K.flatten(K.cast(y_true, 'float32'))
    y_pred_flat = K.flatten(y_pred_pos)
    tp = K.sum(y_true_flat * y_pred_flat)
    fn = K.sum(y_true_flat * (1 - y_pred_flat))
    recall = (tp + smooth) / (tp + fn + smooth)
    return recall

def precision(y_true, y_pred):
    smooth = K.epsilon()
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_true_flat = K.flatten(K.cast(y_true, 'float32'))
    y_pred_flat = K.flatten(y_pred_pos)
    tp = K.sum(y_true_flat * y_pred_flat)
    fp = K.sum((1 - y_true_flat) * y_pred_flat)
    precision = (tp + smooth) / (tp + fp + smooth)
    return precision

# %% [markdown]
# #### Loss

# %%
def dice_loss(y_true, y_pred):
    loss = 1 - dice_score(y_true, y_pred)
    return loss

def iou_loss(y_true, y_pred):
    loss = 1 - iou(y_true, y_pred)
    return loss
    
def focal_loss(y_true, y_pred, gamma=2.0, alpha=0.25):
    epsilon = tf.keras.backend.epsilon()
    y_pred = tf.clip_by_value(y_pred, epsilon, 1.0 - epsilon)
    y_true = tf.cast(y_true, tf.float32)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    focal_weight = alpha * tf.pow(1 - pt, gamma)
    loss = tf.reduce_mean(-focal_weight * tf.math.log(pt))
    return loss

def bce_loss(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=y_true, logits=y_pred))
    return loss

def combined_loss(y_true, y_pred):
    loss = dice_loss(y_true, y_pred) + bce_loss(y_true, y_pred)
    return loss

# %% [markdown]
# #### Cosine annealing

# %%
class SnapshotEnsemble(Callback):
    def __init__(self, n_epochs, n_cycles, lrate_max, verbose=0):
        super(SnapshotEnsemble, self).__init__()
        self.epochs = n_epochs
        self.cycles = n_cycles
        self.lr_max = lrate_max
        self.lrates = list()

    def cosine_annealing(self, epoch, n_epochs, n_cycles, lrate_max):
        epochs_per_cycle = floor(n_epochs / n_cycles)
        cos_inner = (pi * (epoch % epochs_per_cycle)) / epochs_per_cycle
        return lrate_max / 2 * (cos(cos_inner) + 1)

    def on_epoch_begin(self, epoch, logs=None):
        lr = self.cosine_annealing(epoch, self.epochs, self.cycles, self.lr_max)
        self.model.optimizer.learning_rate = lr
        self.lrates.append(lr)
    
    def on_epoch_end(self, epoch, logs={}):
        # check if we can save model
        epochs_per_cycle = (self.epochs / self.cycles)
        if epoch != 0 and (epoch + 1) % epochs_per_cycle == 0:
        # save model to file
            filename = "snapshot_model_%d.h5" % int((epoch + 1) / epochs_per_cycle)
            self.model.save(filename)
            print('>saved snapshot %s, epoch %d' % (filename, epoch))

# %% [markdown]
# ## Model

# %%
def conv_block(x, num_filters, kernel_size, padding="same", use_bias=False, act=True):
    x = Conv2D(num_filters, kernel_size, padding=padding, use_bias=use_bias)(x)
    x = BatchNormalization()(x)
    if act:
        x = Activation("relu")(x)
    return x

def region_aware_attention(x):
    num_filters = x.shape[-1]
    max_pool = GlobalMaxPooling2D()(x)
    avg_pool = GlobalAveragePooling2D()(x)
    
    concat = Concatenate()([max_pool, avg_pool])
    dense = Dense(num_filters, activation='sigmoid')(concat)
    attention = Reshape((1, 1, num_filters))(dense)
    attention = Multiply()([x, attention])
    return attention

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters, 3)
    x = conv_block(x, num_filters, 3)
    s = x
    p = MaxPooling2D((2, 2))(x)
    return s, p

def decoder_block(x, skip, num_filters):
    x = Conv2DTranspose(num_filters, 2, strides=2, padding="same")(x)
    x = Concatenate()([x, skip])
    x = conv_block(x, num_filters, 3)
    x = conv_block(x, num_filters, 3)
    return x

def build_ra_net(shape):
    inputs = Input(shape)

    s1, p1 = encoder_block(inputs, 32)
    s2, p2 = encoder_block(p1, 64)
    s3, p3 = encoder_block(p2, 128)
    s4, p4 = encoder_block(p3, 256)

    bridge = conv_block(p4, 512, 3)
    bridge = region_aware_attention(bridge)

    d1 = decoder_block(bridge, s4, 256)
    d2 = decoder_block(d1, s3, 128)
    d3 = decoder_block(d2, s2, 64)
    d4 = decoder_block(d3, s1, 32)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="RA-Net")
    return model


optimizer = Adam(learning_rate=0.0001)  # Moved optimizer initialization here
model = build_ra_net((512, 512, 3))
model.compile(loss=combined_loss, metrics=["accuracy", dice_score, recall, precision, iou], optimizer=optimizer)
model.summary()
# Out:
# Model: "RA-Net"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 512, 512,  │        864 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 512, 512,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 512, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 512, 512,  │      9,216 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 512,  │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 512, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 256, 256,  │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 256, 256,  │     18,432 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 256, 256,  │     36,864 │ activation_2[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 128, 128,  │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 128,  │     73,728 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 128, 128,  │    147,456 │ activation_4[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 64, 64,    │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │    294,912 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │    589,824 │ activation_6[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 32, 32,    │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │  1,179,648 │ max_pooling2d_3[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      2,048 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ activation_8[0][… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ activation_8[0][… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 1024)      │          0 │ global_max_pooli… │
# │ (Concatenate)       │                   │            │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │    524,800 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 512) │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 32, 32,    │          0 │ activation_8[0][… │
# │                     │ 512)              │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 64, 64,    │    524,544 │ multiply[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │  1,179,648 │ concatenate_1[0]… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 64, 64,    │    589,824 │ activation_9[0][… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 128, 128,  │    131,200 │ activation_10[0]… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │    294,912 │ concatenate_2[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 128, 128,  │    147,456 │ activation_11[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 256, 256,  │     32,832 │ activation_12[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 256, 256,  │     73,728 │ concatenate_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 256, 256,  │     36,864 │ activation_13[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 512, 512,  │      8,224 │ activation_14[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 512, 512,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 512, 512,  │     18,432 │ concatenate_4[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 512,  │        128 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 512, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 512, 512,  │      9,216 │ activation_15[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512, 512,  │        128 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 512, 512,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 512, 512,  │         33 │ activation_16[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,932,385 (22.63 MB)
#  Trainable params: 5,927,521 (22.61 MB)
#  Non-trainable params: 4,864 (19.00 KB)

# %% [markdown]
# ## Training

# %%
n_epochs = 50
n_cycles = n_epochs / 10
ca = SnapshotEnsemble(n_epochs, n_cycles, 0.0001)

history = model.fit(train_dataset,
                    epochs=n_epochs,
                    validation_data=val_dataset,
                    verbose=1,
                    callbacks=[ca],
                    shuffle=True)
# Out:
# Epoch 1/50
# 2024-06-12 07:55:50.944071: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,64,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,64,512,512]{3,2,1,0}, f32[4,32,512,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-06-12 07:55:50.989132: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.045178813s
# Trying algorithm eng0{} for conv (f32[32,64,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,64,512,512]{3,2,1,0}, f32[4,32,512,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-06-12 07:55:53.035840: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng0{} for conv (f32[32,64,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,64,512,512]{3,2,1,0}, f32[4,32,512,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# 2024-06-12 07:55:53.090501: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.054751425s
# Trying algorithm eng0{} for conv (f32[32,64,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,64,512,512]{3,2,1,0}, f32[4,32,512,512]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"conv_result_scale":1,"activation_mode":"kNone","side_input_scale":0,"leakyrelu_alpha":0} is taking a while...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1718178959.058084     335 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1718178959.091996     335 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
#      35/Unknown 96s 301ms/step - accuracy: 0.7808 - dice_score: 0.5048 - iou: 0.3426 - loss: 1.2525 - precision: 0.6280 - recall: 0.7151
# /opt/conda/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# W0000 00:00:1718178971.911288     333 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 99s 385ms/step - accuracy: 0.7815 - dice_score: 0.5063 - iou: 0.3439 - loss: 1.2504 - precision: 0.6291 - recall: 0.7166 - val_accuracy: 0.6541 - val_dice_score: 0.3816 - val_iou: 0.2387 - val_loss: 1.4010 - val_precision: 1.0000 - val_recall: 3.1523e-13
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 315ms/step - accuracy: 0.8845 - dice_score: 0.6899 - iou: 0.5321 - loss: 0.9951 - precision: 0.7828 - recall: 0.8765 - val_accuracy: 0.6541 - val_dice_score: 0.3450 - val_iou: 0.2102 - val_loss: 1.4145 - val_precision: 1.0000 - val_recall: 3.1523e-13
# Epoch 3/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9131 - dice_score: 0.7449 - iou: 0.5997 - loss: 0.9175 - precision: 0.8417 - recall: 0.8936 - val_accuracy: 0.6541 - val_dice_score: 0.2947 - val_iou: 0.1736 - val_loss: 1.4411 - val_precision: 1.0000 - val_recall: 3.1523e-13
# Epoch 4/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9246 - dice_score: 0.7695 - iou: 0.6314 - loss: 0.8834 - precision: 0.8601 - recall: 0.9088 - val_accuracy: 0.6541 - val_dice_score: 0.2551 - val_iou: 0.1465 - val_loss: 1.4670 - val_precision: 1.0000 - val_recall: 3.1523e-13
# Epoch 5/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - accuracy: 0.9332 - dice_score: 0.7851 - iou: 0.6515 - loss: 0.8617 - precision: 0.8722 - recall: 0.9193 - val_accuracy: 0.6541 - val_dice_score: 0.2379 - val_iou: 0.1352 - val_loss: 1.4790 - val_precision: 1.0000 - val_recall: 3.1523e-13
# Epoch 6/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - accuracy: 0.9450 - dice_score: 0.8047 - iou: 0.6785 - loss: 0.8353 - precision: 0.8878 - recall: 0.9392 - val_accuracy: 0.6541 - val_dice_score: 0.2031 - val_iou: 0.1132 - val_loss: 1.5101 - val_precision: 1.0000 - val_recall: 3.1523e-13
# Epoch 7/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9512 - dice_score: 0.8151 - iou: 0.6932 - loss: 0.8210 - precision: 0.8962 - recall: 0.9483 - val_accuracy: 0.6541 - val_dice_score: 0.1902 - val_iou: 0.1052 - val_loss: 1.5207 - val_precision: 1.0000 - val_recall: 3.1523e-13
# Epoch 8/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9610 - dice_score: 0.8265 - iou: 0.7087 - loss: 0.8049 - precision: 0.9222 - recall: 0.9533 - val_accuracy: 0.6562 - val_dice_score: 0.1818 - val_iou: 0.1002 - val_loss: 1.5261 - val_precision: 1.0000 - val_recall: 0.0061
# Epoch 9/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9641 - dice_score: 0.8331 - iou: 0.7187 - loss: 0.7962 - precision: 0.9236 - recall: 0.9616 - val_accuracy: 0.6833 - val_dice_score: 0.2567 - val_iou: 0.1576 - val_loss: 1.4408 - val_precision: 0.9999 - val_recall: 0.0836
# Epoch 10/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9653 - dice_score: 0.8372 - iou: 0.7247 - loss: 0.7916 - precision: 0.9183 - recall: 0.9713>saved snapshot snapshot_model_1.h5, epoch 9
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 324ms/step - accuracy: 0.9652 - dice_score: 0.8368 - iou: 0.7241 - loss: 0.7920 - precision: 0.9183 - recall: 0.9709 - val_accuracy: 0.7562 - val_dice_score: 0.4484 - val_iou: 0.3057 - val_loss: 1.2271 - val_precision: 0.9852 - val_recall: 0.3107
# Epoch 11/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 315ms/step - accuracy: 0.9600 - dice_score: 0.8317 - iou: 0.7166 - loss: 0.7987 - precision: 0.9118 - recall: 0.9612 - val_accuracy: 0.7930 - val_dice_score: 0.5719 - val_iou: 0.4192 - val_loss: 1.0944 - val_precision: 0.8776 - val_recall: 0.4920
# Epoch 12/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 315ms/step - accuracy: 0.9493 - dice_score: 0.8236 - iou: 0.7046 - loss: 0.8086 - precision: 0.9034 - recall: 0.9354 - val_accuracy: 0.8571 - val_dice_score: 0.6811 - val_iou: 0.5301 - val_loss: 0.9701 - val_precision: 0.8859 - val_recall: 0.6658
# Epoch 13/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 315ms/step - accuracy: 0.9542 - dice_score: 0.8343 - iou: 0.7205 - loss: 0.7945 - precision: 0.9102 - recall: 0.9451 - val_accuracy: 0.9082 - val_dice_score: 0.7828 - val_iou: 0.6510 - val_loss: 0.8425 - val_precision: 0.9161 - val_recall: 0.8050
# Epoch 14/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 315ms/step - accuracy: 0.9601 - dice_score: 0.8451 - iou: 0.7363 - loss: 0.7795 - precision: 0.9207 - recall: 0.9512 - val_accuracy: 0.9287 - val_dice_score: 0.8259 - val_iou: 0.7077 - val_loss: 0.7954 - val_precision: 0.8799 - val_recall: 0.9126
# Epoch 15/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 315ms/step - accuracy: 0.9603 - dice_score: 0.8508 - iou: 0.7448 - loss: 0.7723 - precision: 0.9151 - recall: 0.9576 - val_accuracy: 0.9241 - val_dice_score: 0.8145 - val_iou: 0.6971 - val_loss: 0.8024 - val_precision: 0.9178 - val_recall: 0.8517
# Epoch 16/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9625 - dice_score: 0.8557 - iou: 0.7516 - loss: 0.7658 - precision: 0.9201 - recall: 0.9608 - val_accuracy: 0.9306 - val_dice_score: 0.8202 - val_iou: 0.7052 - val_loss: 0.7957 - val_precision: 0.9172 - val_recall: 0.8666
# Epoch 17/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9709 - dice_score: 0.8660 - iou: 0.7675 - loss: 0.7511 - precision: 0.9411 - recall: 0.9626 - val_accuracy: 0.9341 - val_dice_score: 0.8275 - val_iou: 0.7149 - val_loss: 0.7829 - val_precision: 0.9550 - val_recall: 0.8482
# Epoch 18/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9755 - dice_score: 0.8734 - iou: 0.7789 - loss: 0.7410 - precision: 0.9520 - recall: 0.9674 - val_accuracy: 0.9361 - val_dice_score: 0.8340 - val_iou: 0.7230 - val_loss: 0.7748 - val_precision: 0.9552 - val_recall: 0.8577
# Epoch 19/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9767 - dice_score: 0.8769 - iou: 0.7844 - loss: 0.7367 - precision: 0.9501 - recall: 0.9736 - val_accuracy: 0.9374 - val_dice_score: 0.8356 - val_iou: 0.7247 - val_loss: 0.7733 - val_precision: 0.9482 - val_recall: 0.8657
# Epoch 20/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9781 - dice_score: 0.8793 - iou: 0.7881 - loss: 0.7338 - precision: 0.9507 - recall: 0.9774>saved snapshot snapshot_model_2.h5, epoch 19
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 321ms/step - accuracy: 0.9780 - dice_score: 0.8790 - iou: 0.7877 - loss: 0.7341 - precision: 0.9506 - recall: 0.9773 - val_accuracy: 0.9372 - val_dice_score: 0.8355 - val_iou: 0.7242 - val_loss: 0.7737 - val_precision: 0.9466 - val_recall: 0.8676
# Epoch 21/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9768 - dice_score: 0.8782 - iou: 0.7864 - loss: 0.7349 - precision: 0.9512 - recall: 0.9730 - val_accuracy: 0.9367 - val_dice_score: 0.8379 - val_iou: 0.7255 - val_loss: 0.7739 - val_precision: 0.9281 - val_recall: 0.8875
# Epoch 22/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - accuracy: 0.9705 - dice_score: 0.8753 - iou: 0.7818 - loss: 0.7389 - precision: 0.9402 - recall: 0.9645 - val_accuracy: 0.9387 - val_dice_score: 0.8412 - val_iou: 0.7342 - val_loss: 0.7653 - val_precision: 0.9509 - val_recall: 0.8625
# Epoch 23/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - accuracy: 0.9651 - dice_score: 0.8707 - iou: 0.7740 - loss: 0.7451 - precision: 0.9314 - recall: 0.9573 - val_accuracy: 0.9153 - val_dice_score: 0.8360 - val_iou: 0.7209 - val_loss: 0.7832 - val_precision: 0.8661 - val_recall: 0.8987
# Epoch 24/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9629 - dice_score: 0.8713 - iou: 0.7760 - loss: 0.7444 - precision: 0.9221 - recall: 0.9581 - val_accuracy: 0.9285 - val_dice_score: 0.8383 - val_iou: 0.7245 - val_loss: 0.7800 - val_precision: 0.8913 - val_recall: 0.9130
# Epoch 25/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9726 - dice_score: 0.8861 - iou: 0.7990 - loss: 0.7246 - precision: 0.9386 - recall: 0.9705 - val_accuracy: 0.9157 - val_dice_score: 0.8077 - val_iou: 0.6806 - val_loss: 0.8286 - val_precision: 0.8417 - val_recall: 0.9352
# Epoch 26/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9673 - dice_score: 0.8788 - iou: 0.7869 - loss: 0.7331 - precision: 0.9470 - recall: 0.9470 - val_accuracy: 0.9175 - val_dice_score: 0.8207 - val_iou: 0.7010 - val_loss: 0.7923 - val_precision: 0.9259 - val_recall: 0.8279
# Epoch 27/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - accuracy: 0.9772 - dice_score: 0.8946 - iou: 0.8123 - loss: 0.7127 - precision: 0.9542 - recall: 0.9690 - val_accuracy: 0.9301 - val_dice_score: 0.8396 - val_iou: 0.7262 - val_loss: 0.7684 - val_precision: 0.9400 - val_recall: 0.8488
# Epoch 28/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - accuracy: 0.9795 - dice_score: 0.8969 - iou: 0.8162 - loss: 0.7089 - precision: 0.9651 - recall: 0.9651 - val_accuracy: 0.9380 - val_dice_score: 0.8556 - val_iou: 0.7508 - val_loss: 0.7478 - val_precision: 0.9464 - val_recall: 0.8700
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9811 - dice_score: 0.9021 - iou: 0.8244 - loss: 0.7029 - precision: 0.9624 - recall: 0.9748 - val_accuracy: 0.9379 - val_dice_score: 0.8568 - val_iou: 0.7524 - val_loss: 0.7478 - val_precision: 0.9344 - val_recall: 0.8835
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - accuracy: 0.9824 - dice_score: 0.9048 - iou: 0.8289 - loss: 0.6997 - precision: 0.9596 - recall: 0.9813>saved snapshot snapshot_model_3.h5, epoch 29
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 321ms/step - accuracy: 0.9824 - dice_score: 0.9046 - iou: 0.8286 - loss: 0.6999 - precision: 0.9596 - recall: 0.9813 - val_accuracy: 0.9387 - val_dice_score: 0.8572 - val_iou: 0.7533 - val_loss: 0.7468 - val_precision: 0.9379 - val_recall: 0.8820
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - accuracy: 0.9824 - dice_score: 0.9045 - iou: 0.8285 - loss: 0.6996 - precision: 0.9632 - recall: 0.9771 - val_accuracy: 0.9298 - val_dice_score: 0.8412 - val_iou: 0.7279 - val_loss: 0.7682 - val_precision: 0.9252 - val_recall: 0.8694
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9778 - dice_score: 0.9025 - iou: 0.8251 - loss: 0.7026 - precision: 0.9539 - recall: 0.9726 - val_accuracy: 0.9413 - val_dice_score: 0.8616 - val_iou: 0.7589 - val_loss: 0.7420 - val_precision: 0.9405 - val_recall: 0.8920
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9760 - dice_score: 0.9023 - iou: 0.8247 - loss: 0.7027 - precision: 0.9549 - recall: 0.9664 - val_accuracy: 0.8930 - val_dice_score: 0.7823 - val_iou: 0.6482 - val_loss: 0.8374 - val_precision: 0.9026 - val_recall: 0.7628
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9735 - dice_score: 0.9010 - iou: 0.8223 - loss: 0.7046 - precision: 0.9479 - recall: 0.9655 - val_accuracy: 0.9162 - val_dice_score: 0.8400 - val_iou: 0.7272 - val_loss: 0.7788 - val_precision: 0.8532 - val_recall: 0.9180
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9760 - dice_score: 0.9068 - iou: 0.8320 - loss: 0.6969 - precision: 0.9532 - recall: 0.9688 - val_accuracy: 0.9340 - val_dice_score: 0.8535 - val_iou: 0.7529 - val_loss: 0.7453 - val_precision: 0.9759 - val_recall: 0.8287
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9820 - dice_score: 0.9155 - iou: 0.8465 - loss: 0.6852 - precision: 0.9641 - recall: 0.9755 - val_accuracy: 0.9352 - val_dice_score: 0.8581 - val_iou: 0.7540 - val_loss: 0.7449 - val_precision: 0.9407 - val_recall: 0.8678
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9845 - dice_score: 0.9195 - iou: 0.8531 - loss: 0.6795 - precision: 0.9738 - recall: 0.9733 - val_accuracy: 0.9404 - val_dice_score: 0.8654 - val_iou: 0.7668 - val_loss: 0.7339 - val_precision: 0.9540 - val_recall: 0.8689
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9856 - dice_score: 0.9223 - iou: 0.8580 - loss: 0.6759 - precision: 0.9736 - recall: 0.9770 - val_accuracy: 0.9422 - val_dice_score: 0.8703 - val_iou: 0.7739 - val_loss: 0.7282 - val_precision: 0.9522 - val_recall: 0.8773
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 315ms/step - accuracy: 0.9862 - dice_score: 0.9238 - iou: 0.8606 - loss: 0.6739 - precision: 0.9744 - recall: 0.9783 - val_accuracy: 0.9412 - val_dice_score: 0.8707 - val_iou: 0.7741 - val_loss: 0.7289 - val_precision: 0.9409 - val_recall: 0.8860
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9865 - dice_score: 0.9256 - iou: 0.8635 - loss: 0.6723 - precision: 0.9683 - recall: 0.9859>saved snapshot snapshot_model_4.h5, epoch 39
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 321ms/step - accuracy: 0.9865 - dice_score: 0.9254 - iou: 0.8632 - loss: 0.6725 - precision: 0.9683 - recall: 0.9858 - val_accuracy: 0.9412 - val_dice_score: 0.8701 - val_iou: 0.7737 - val_loss: 0.7292 - val_precision: 0.9439 - val_recall: 0.8830
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9869 - dice_score: 0.9259 - iou: 0.8641 - loss: 0.6714 - precision: 0.9738 - recall: 0.9815 - val_accuracy: 0.9324 - val_dice_score: 0.8620 - val_iou: 0.7603 - val_loss: 0.7427 - val_precision: 0.9191 - val_recall: 0.8884
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9853 - dice_score: 0.9259 - iou: 0.8642 - loss: 0.6715 - precision: 0.9693 - recall: 0.9799 - val_accuracy: 0.9206 - val_dice_score: 0.8494 - val_iou: 0.7415 - val_loss: 0.7599 - val_precision: 0.9058 - val_recall: 0.8706
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9755 - dice_score: 0.9140 - iou: 0.8441 - loss: 0.6872 - precision: 0.9523 - recall: 0.9654 - val_accuracy: 0.9103 - val_dice_score: 0.8366 - val_iou: 0.7220 - val_loss: 0.7790 - val_precision: 0.8733 - val_recall: 0.8773
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9671 - dice_score: 0.9067 - iou: 0.8318 - loss: 0.6979 - precision: 0.9353 - recall: 0.9624 - val_accuracy: 0.9313 - val_dice_score: 0.8606 - val_iou: 0.7634 - val_loss: 0.7420 - val_precision: 0.9178 - val_recall: 0.8767
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 314ms/step - accuracy: 0.9736 - dice_score: 0.9147 - iou: 0.8448 - loss: 0.6867 - precision: 0.9471 - recall: 0.9663 - val_accuracy: 0.9205 - val_dice_score: 0.8396 - val_iou: 0.7287 - val_loss: 0.7660 - val_precision: 0.9334 - val_recall: 0.8250
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - accuracy: 0.9792 - dice_score: 0.9220 - iou: 0.8570 - loss: 0.6761 - precision: 0.9668 - recall: 0.9628 - val_accuracy: 0.9391 - val_dice_score: 0.8758 - val_iou: 0.7827 - val_loss: 0.7250 - val_precision: 0.9181 - val_recall: 0.9045
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - accuracy: 0.9823 - dice_score: 0.9283 - iou: 0.8681 - loss: 0.6684 - precision: 0.9645 - recall: 0.9751 - val_accuracy: 0.9361 - val_dice_score: 0.8736 - val_iou: 0.7784 - val_loss: 0.7287 - val_precision: 0.9133 - val_recall: 0.9033
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - accuracy: 0.9836 - dice_score: 0.9306 - iou: 0.8718 - loss: 0.6651 - precision: 0.9725 - recall: 0.9721 - val_accuracy: 0.9362 - val_dice_score: 0.8698 - val_iou: 0.7743 - val_loss: 0.7296 - val_precision: 0.9369 - val_recall: 0.8767
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 313ms/step - accuracy: 0.9860 - dice_score: 0.9346 - iou: 0.8788 - loss: 0.6598 - precision: 0.9770 - recall: 0.9754 - val_accuracy: 0.9377 - val_dice_score: 0.8744 - val_iou: 0.7807 - val_loss: 0.7250 - val_precision: 0.9300 - val_recall: 0.8890
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.9872 - dice_score: 0.9372 - iou: 0.8834 - loss: 0.6569 - precision: 0.9738 - recall: 0.9828>saved snapshot snapshot_model_5.h5, epoch 49
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 321ms/step - accuracy: 0.9872 - dice_score: 0.9371 - iou: 0.8832 - loss: 0.6570 - precision: 0.9738 - recall: 0.9828 - val_accuracy: 0.9370 - val_dice_score: 0.8726 - val_iou: 0.7783 - val_loss: 0.7268 - val_precision: 0.9329 - val_recall: 0.8836

# %% [markdown]
# #### Training curves

# %%
def Train_Val_Plot(loss, val_loss, dice_score, val_dice_score, iou, val_iou, recall, val_recall, precision, val_precision, accuracy, val_accuracy):
    fig, axs = plt.subplots(2, 3, figsize=(20, 10))
    fig.suptitle("MODEL'S METRICS VISUALIZATION")

    # Loss plot
    axs[0, 0].plot(range(1, len(loss) + 1), loss)
    axs[0, 0].plot(range(1, len(val_loss) + 1), val_loss)
    axs[0, 0].set_title('History of Loss')
    axs[0, 0].set_xlabel('Epochs')
    axs[0, 0].set_ylabel('Loss')
    axs[0, 0].legend(['training', 'validation'])

    # Dice Coefficient plot
    axs[0, 1].plot(range(1, len(dice_score) + 1), dice_score)
    axs[0, 1].plot(range(1, len(val_dice_score) + 1), val_dice_score)
    axs[0, 1].set_title('History of Dice Coefficient')
    axs[0, 1].set_xlabel('Epochs')
    axs[0, 1].set_ylabel('Dice Coefficient')
    axs[0, 1].legend(['training', 'validation'])

    # Mean IOU plot
    axs[0, 2].plot(range(1, len(iou) + 1), iou)
    axs[0, 2].plot(range(1, len(val_iou) + 1), val_iou)
    axs[0, 2].set_title('History of IOU')
    axs[0, 2].set_xlabel('Epochs')
    axs[0, 2].set_ylabel('IOU')
    axs[0, 2].legend(['training', 'validation'])

    # Recall plot
    axs[1, 0].plot(range(1, len(recall) + 1), recall)
    axs[1, 0].plot(range(1, len(val_recall) + 1), val_recall)
    axs[1, 0].set_title('History of Recall')
    axs[1, 0].set_xlabel('Epochs')
    axs[1, 0].set_ylabel('Recall')
    axs[1, 0].legend(['training', 'validation'])

    # Precision plot
    axs[1, 1].plot(range(1, len(precision) + 1), precision)
    axs[1, 1].plot(range(1, len(val_precision) + 1), val_precision)
    axs[1, 1].set_title('History of Precision')
    axs[1, 1].set_xlabel('Epochs')
    axs[1, 1].set_ylabel('Precision')
    axs[1, 1].legend(['training', 'validation'])

    # Accuracy plot
    axs[1, 2].plot(range(1, len(accuracy) + 1), accuracy)
    axs[1, 2].plot(range(1, len(val_accuracy) + 1), val_accuracy)
    axs[1, 2].set_title('History of Accuracy')
    axs[1, 2].set_xlabel('Epochs')
    axs[1, 2].set_ylabel('Accuracy')
    axs[1, 2].legend(['training', 'validation'])

    plt.tight_layout()
    plt.show()

Train_Val_Plot(
    history.history['loss'], history.history['val_loss'],
    history.history['dice_score'], history.history['val_dice_score'],
    history.history['iou'], history.history['val_iou'],
    history.history['recall'], history.history['val_recall'],
    history.history['precision'], history.history['val_precision'],
    history.history['accuracy'], history.history['val_accuracy']
)

# %% [markdown]
# ## Testing

# %%
model.load_weights("/kaggle/working/snapshot_model_1.h5")
model.evaluate(test_dataset, verbose = 1)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - accuracy: 0.7376 - dice_score: 0.3693 - iou: 0.2369 - loss: 1.3195 - precision: 0.9657 - recall: 0.2170
# [1.2362639904022217,
#  0.7458211183547974,
#  0.4401059150695801,
#  0.2898196876049042,
#  0.9517364501953125,
#  0.29409244656562805]

# %%
model.load_weights("/kaggle/working/snapshot_model_2.h5")
model.evaluate(test_dataset, verbose = 1)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9533 - dice_score: 0.8595 - iou: 0.7551 - loss: 0.7520 - precision: 0.9397 - recall: 0.9168
# [0.7345908880233765,
#  0.9534378051757812,
#  0.8675590753555298,
#  0.9210155606269836,
#  0.9422352910041809,
#  0.7682574987411499]

# %%
model.load_weights("/kaggle/working/snapshot_model_3.h5")
model.evaluate(test_dataset, verbose = 1)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9594 - dice_score: 0.8867 - iou: 0.7974 - loss: 0.7162 - precision: 0.9493 - recall: 0.9292
# [0.7032286524772644,
#  0.9582235217094421,
#  0.8913442492485046,
#  0.9331755638122559,
#  0.9473733901977539,
#  0.8053668737411499]

# %%
model.load_weights("/kaggle/working/snapshot_model_4.h5")
model.evaluate(test_dataset, verbose = 1)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9587 - dice_score: 0.8960 - iou: 0.8125 - loss: 0.7032 - precision: 0.9516 - recall: 0.9222
# [0.6907891035079956,
#  0.9570220708847046,
#  0.9001924395561218,
#  0.9267519116401672,
#  0.9490182995796204,
#  0.8196773529052734]

# %%
model.load_weights("/kaggle/working/snapshot_model_5.h5")
model.evaluate(test_dataset, verbose = 1)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.9588 - dice_score: 0.9049 - iou: 0.8271 - loss: 0.6912 - precision: 0.9542 - recall: 0.9193
# [0.6784831285476685,
#  0.957960307598114,
#  0.9091708064079285,
#  0.9254862070083618,
#  0.9517022967338562,
#  0.834621787071228]
